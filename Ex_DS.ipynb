# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.     לקלוט את קובץ הנתונים לפייטון

# %%
path = r'C:\Users\mehes\Desktop\gstat\DS_Exam.xlsx'
df = pd.read_excel(path, usecols="A:W", sheet_name= 'Python' ,header = 22)

# %% [markdown]
# ### 2.להציג בצורה ויזואלית את התפלגות המשתנה החזוי Future_hour_income  (יש לצרף סקריפט ופלטים)
# ##### לא נראה לי הגיוני שהערך של השכר לשעה שווה 0 ולכן התייחסתי ל0 כערך חסרה

# %%
df.future_hour_income[df.future_hour_income != 0].describe()
sns.distplot(df.future_hour_income[df.future_hour_income != 0])
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ###  3. להציג בצורה ויזואלית שלשה משתנים בעלי השפעה על משתנה ה  incomeGroupUp  (יש לצרף סקריפט ופלטים)  הסבר מילולי על הקשרים
#
# #### *בחרתי פיישרט ככה יותר קל לראות את ההבדלים בין ההתפלגויות בגלל שהדטסט לא מאוזן*

# %%
fig = plt.figure(figsize = (15,15))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax1.title.set_text('Income is up')
ax2.title.set_text('Income is not up')
plt.subplot(221)
df.matzavbriut[df.incomeGroupUp == True].value_counts().plot.pie()
plt.subplot(222)
df.matzavbriut[df.incomeGroupUp == False].value_counts().plot.pie()
'''
We can suppose that proportion of people with health condition not good or not good at all
is greater in the second chart. Probably a not good condition health increace the chance
that the income will not go up.
'''
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %% [markdown]
# ###### *We can suppose that proportion of people with health condition not good or not good at all is greater in the second chart. Probably a not good condition health increace the chance* that the income will not go up.

# %%
fig = plt.figure(figsize = (15,15))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax1.title.set_text('IncomeGroup is up')
ax2.title.set_text('IncomeGroup is not up')
plt.subplot(221)
df.labour_force_participation[df.incomeGroupUp == True].value_counts().plot.pie()
plt.subplot(222)
df.labour_force_participation[df.incomeGroupUp == False].value_counts().plot.pie()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %% [markdown]
# #### *We can see that proportion of participation to labour force is greater in the first chart. Probably that when there is a participation to the labour force it's increase the chance that the income will go up.*

# %%
fig = plt.figure(figsize = (15,15))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax1.title.set_text('IncomeGroup is up')
ax2.title.set_text('IncomeGroup is not up')
plt.subplot(221)
df.chipesshana[df.incomeGroupUp == True].value_counts().plot.pie()
plt.subplot(222)
df.chipesshana[df.incomeGroupUp == False].value_counts().plot.pie()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %% [markdown]
# #### *Probably that job search increase the chance that the income will go up.*

# %% [markdown]
# ### 4. במידה והיית בונה מודלים  לחיזוי ערכי  ה  incomeGroupUp  ,   Future_hour_income  על סמך שאר השדות, איזה מודל נתונים יכול להתאים?

# %% [markdown]
# #### *To predict Future_hour_income i would use a regression model like Randomforestregressor.*
# #### *To predict incomeGroupUp i would use RandomforestClassifier.*

# %% [markdown]
# ### 5. כיצד היית מתקף את תוצאות המודל

# %% [markdown]
# #####  For Future_hour_income i would verify the MSE.
# #####  For incomeGroupUp i would verify the accuracy.
